# %%
import pandas as pd
import datetime
import os

# %%
stations_path = "datasets/estacions/"
info_path = "datasets/informació/"

feb_data = pd.read_csv(info_path + "2020_02_Febrer_BicingNou_INFORMACIO.csv")
mar_data = pd.read_csv(info_path + "2020_03_Marc_BicingNou_INFORMACIO.csv")
abr_data = pd.read_csv(info_path + "2020_04_Abril_BicingNou_INFORMACIO.csv")

# %%
for row in feb_data[["station_id", "capacity"]].groupby(by="station_id"):
    print(row[1]["capacity"].value_counts())
# Out:
# 46    8347
# Name: capacity, dtype: int64
# 27    8347
# Name: capacity, dtype: int64
# 27    8341
# Name: capacity, dtype: int64
# 21    8347
# Name: capacity, dtype: int64
# 39    8347
# Name: capacity, dtype: int64
# 39    8329
# Name: capacity, dtype: int64
# 27    8347
# Name: capacity, dtype: int64
# 27    8347
# Name: capacity, dtype: int64
# 27    8218
# Name: capacity, dtype: int64
# 21    8347
# Name: capacity, dtype: int64
# 26    8338
# Name: capacity, dtype: int64
# 54    8347
# Name: capacity, dtype: int64
# 27    8216
# Name: capacity, dtype: int64
# 21    8340
# Name: capacity, dtype: int64
# 42    8347
# Name: capacity, dtype: int64
# 27    8347
# Name: capacity, dtype: int64
# 30    8347
# Name: capacity, dtype: int64
# 18    8176
# Name: capacity, dtype: int64
# 21    8220
# Name: capacity, dtype: int64
# 19    8347
# Name: capacity, dtype: int64
# 27    8347
# Name: capacity, dtype: int64
# 30    8347
# Name: capacity, dtype: int64
# 21    8343
# ...
